# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeChari/Character_Pattern_Recognition_Python/blob/master/juxt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f = open("input.txt")

# %%
print(f.read())
# Out:
#  _  _  _        _     _  _
# |_ | || |  ||_| _|  ||_ |_
# |_||_||_|  |  | _|  | _| _|
#
#  _  _  _     _  _     _
# |_ |_ | ||_|| ||_||_||_ |_|
# |_| _||_|  ||_||_|  | _|  |
#
#  _  _  _  _  _  _  _  _
#  _||_|  || ||_   || | _|  |
#  _||_|  ||_| _|  ||_||_   |
#
#  _        _  _  _  _  _  _
#  _||_|  |  | _||_ |_   ||_|
#  _|  |  |  ||_  _| _|  | _|
#
#     _  _     _  _     _  _
# |_||_ |_|  |  ||_||_||_||_|
#   | _| _|  |  | _|  ||_| _|
#
#     _  _  _     _  _  _  _
# |_||_||_ |_ |_|| | _||_ |_|
#   ||_| _||_|  ||_| _||_||_|
#
#  _        _  _  _     _  _
# |_ |_|  | _||_ |_   ||_| _|
# |_|  |  | _||_||_|  ||_| _|
#
#  _  _  _  _  _  _  _
#   || | _||_||_||_| _|  |  |
#   ||_||_  _| _||_| _|  |  |
#
#  _  _  _  _  _  _  _  _  _
#   ||_||_| _|  | _||_||_ | |
#   ||_||_||_   ||_  _| _||_|
#
#  _  _  _  _  _     _  _  _
# |_ |_ |_  _|| |  | _| _| _|
# |_| _| _| _||_|  ||_  _||_
#
#  _  _        _     _  _  _
#   | _|  ||_||_|  ||_| _||_
#   ||_   |  | _|  | _| _||_|
#
# ...

# %% [markdown]
# # New Section
